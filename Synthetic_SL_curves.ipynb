# %% [markdown]
# ## This code generates synthetic sea-level curves for Badlands
# ## This code generates waves of different amplitude and frequency, based on the sine function.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Dividing the diff of 3pi and 1pi by 100 gives me the number of points I want
geo_wave_100=np.arange(-3*np.pi, -1*np.pi, (((3*np.pi)-(1*np.pi))/1e2))
geo_wave_1000=np.arange(-3*np.pi, -1*np.pi, (((3*np.pi)-(1*np.pi))/1e3)); #print (len(geo_wave_1000))
geo_wave_10000=np.arange(-3*np.pi, -1*np.pi, (((3*np.pi)-(1*np.pi))/1e4)); #print (len(geo_wave_1000))

start_time=2e6
end_time=12e6
res100k= 1e5
res10k= 1e4
res1k=1e3
years_res1k=(np.arange(start_time,end_time,res1k))
years_res10k=(np.arange(start_time,end_time,res10k))
years_res100k=(np.arange(start_time,end_time,res100k))

print ('number of points in geo_wave_100',len(geo_wave_100))
#print('temporal resultion of geo_wave_100', geo_wave_100[1]-geo_wave_100[0])
print( 'number of points in years_res100k',(len(years_res100k)))
print('temporal resultion of years_res100k is', years_res100k[1]-years_res100k[0])



print ('number of points in years_res10k', (len(years_res10k)))
print ('number of points in geo_wave_1000',len(geo_wave_1000))
print('temporal resultion of years_res10k is', years_res10k[1]-years_res10k[0])
# Out:
# number of points in geo_wave_100 100
# number of points in years_res100k 100
# temporal resultion of years_res100k is 100000.0
# number of points in years_res10k 1000
# number of points in geo_wave_1000 1000
# temporal resultion of years_res10k is 10000.0

# %%
A10m=10 #This means amplitude is -12.5 and +12.5
A25m=25 #This means amplitude is -25 and +25
A50m=50#This means amplitude is -50 and +50
f_0_1Ma=-10e6/.1e6 #100 full cycles, a cycle every 0.1 Ma I made negative so that SL is low and delta progrades easily
f_0_5Ma=-10e6/.5e6 #20 full cycles, a cycle every 0.5 Ma I made negative so that SL is low and delta progrades easily
f_5Ma=-10e6/5e6 #2 full cycles, a cycle every 5 Ma I made negative so that SL is low and delta progrades easily

# %%
rounding=2
plt.figure(figsize=(10,5))
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_0_1Ma),rounding)*A25m, '-o',label="A=25m, f=0.1Ma")
plt.plot(years_res10k,np.round(np.sin(geo_wave_1000*f_0_5Ma),rounding)*A25m, '-o',label="A=25m, f=0.5Ma")
plt.plot(years_res100k,np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A25m, '-o',label="A=25m, f=5Ma")
plt.axhline(max(np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A25m), c='r')# Making sure that the maximum values acrually go to 25, that's why I need to do the rounding 
plt.legend()

# %%
rounding=2
plt.figure(figsize=(10,5))
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_0_1Ma),rounding)*A25m, '-o',label="A=25m, f=0.1Ma")
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A25m, '-o',label="A=25m, f=0.5Ma")
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_5Ma),rounding)*A25m, '-o',label="A=25m, f=5Ma")
plt.axhline(max(np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A25m), c='r')# Making sure that the maximum values acrually go to 25, that's why I need to do the rounding 
plt.legend()

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_5Ma),rounding)*A25m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y, '-o') 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/f5Myr_A25m.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A25m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y) 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/f500Kyr_A25m.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_0_1Ma),rounding)*A25m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y) 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/f100Kyr_A25m.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma

# %%
rounding=2
plt.figure(figsize=(10,5))
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_0_1Ma),rounding)*A10m, '-o',label="A=10m, f=0.5Ma")
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A25m, '-o',label="A=25m, f=0.5Ma")
plt.plot(years_res1k,np.round(np.sin(geo_wave_10000*f_5Ma),rounding)*A50m, '-o',label="A=50m, f=0.5Ma")
plt.axhline(max(np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A10m))# Making sure that the maximum values actually go to 25, that's why I need to do the rounding 
plt.axhline(max(np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A25m))# Making sure that the maximum values actually go to 25, that's why I need to do the rounding 
plt.axhline(max(np.round(np.sin(geo_wave_100*f_5Ma),rounding)*A50m))# Making sure that the maximum values actually go to 25, that's why I need to do the rounding 

plt.legend()

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A10m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y) 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/A10m_f500Kyr.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A25m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y) 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/A25m_f500Kyr.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma

# %%
x=np.append(np.zeros(len(np.arange(0,2e6,res1k))), np.round(np.sin(geo_wave_10000*f_0_5Ma),rounding)*A50m)
y=np.append(np.arange(0,2e6,res1k), years_res1k)
plt.plot(x,y) 
df=pd.DataFrame(x,y) 
df.to_csv('/Volumes/SEMP_4T/Delta_2020/Delta_running/data/A50m_f500Kyr.csv', header=False, sep=' ')#badlands requires the file to be space separated, not coma
